# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
health=pd.read_csv("Downloads\health.txt",sep=",")

# %%
health
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             274 non-null    int64
#  1   Country          274 non-null    object
#  2   Spending_USD     274 non-null    float64
#  3   Life_Expectancy  274 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
health.shape
# Out:
# (274, 4)

# %%
health.columns
# Out:
# Index(['Year', 'Country', 'Spending_USD', 'Life_Expectancy'], dtype='object')

# %%
health.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %%
health['Year'].nunique()
# Out:
# 51

# %%
health['Year'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
health['Country'].unique()
# Out:
# array(['Germany', 'France', 'Great Britain', 'Japan', 'USA', 'Canada'],
#       dtype=object)

# %%
health.isnull().sum()
# Out:
# Year               0
# Country            0
# Spending_USD       0
# Life_Expectancy    0
# dtype: int64

# %%
plt.title("Spending_USD vs country")
plt.ylabel('Spending in US dollar')
plt.xlabel("Country")
sns.set_style('darkgrid')
sns.lineplot(x='Country',y='Spending_USD',data=health)

sns.despine() # to remove the spine that is outer box of the graph
plt.figure(figsize=(10,10))

# %%
plt.title("Spending_USD vs country")
plt.ylabel('Spending in US dollar')
plt.xlabel("Country")
sns.set_style('darkgrid')
sns.barplot(x='Country',y='Spending_USD',data=health)

sns.despine() # to remove the spine that is outer box of the graph
plt.figure(figsize=(10,10))

# %%
plt.title("Spending_USD vs country")
plt.ylabel('Spending in US dollar')
plt.xlabel("Country")
sns.set_style('darkgrid')
sns.scatterplot(x='Year',y='Spending_USD',hue='Country',data=health)

sns.despine() # to remove the spine that is outer box of the graph
plt.figure(figsize=(10,10))

# %%
plt.title("Spending_USD vs country")
plt.ylabel('Spending in US dollar')
plt.xlabel("Country")
sns.set_style('darkgrid')
sns.scatterplot(x='Year',y='Life_Expectancy',hue='Country',data=health)

sns.despine() # to remove the spine that is outer box of the graph
plt.figure(figsize=(10,10))

# %%
plt.title("Spending_USD vs country")
plt.ylabel('Spending in US dollar')
plt.xlabel("Country")
sns.set_style('darkgrid')
sns.scatterplot(x='Year',y='Life_Expectancy',hue='Country',data=health)


sns.despine() # to remove the spine that is outer box of the graph
plt.figure(figsize=(10,10))

# %%
plt.rc("figure", figsize=(45 , 10))
leg=sns.FacetGrid(health,col='Country',hue='Country', height=5, aspect=.65)
leg.map(sns.lineplot,'Spending_USD','Life_Expectancy').add_legend()

# %%
#vertical barchart
plt.figure(figsize=(8,8))
sns.barplot(x='Country',
            y='Spending_USD',
            data=health
           )
# Out:
# <Axes: xlabel='Country', ylabel='Spending_USD'>

# %%
#Horizontal barchart with exchange in variables
plt.figure(figsize=(8,8))
sns.barplot(x='Spending_USD',y='Country',data=health,
            color='Green',
            errorbar=None #used to delete error in bar
           )
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Country'>

# %%
sns.lineplot(y='Life_Expectancy',x='Spending_USD',hue='Country',data=health)
# Out:
# <Axes: xlabel='Spending_USD', ylabel='Life_Expectancy'>

# %%
plt.figure(figsize=(7,7))
sns.countplot(x='Country',data=health)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
data = {'labels': ['A', 'B', 'C', 'D'],
        'values': [20, 35, 25, 20]}
df = pd.DataFrame(data)
plt.figure(figsize=(8,8))
plt.pie(df['values'], labels=df['labels'], autopct='%1.1f%%',explode=[0.1,0,0,0],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2766cac5910>,
# ...
#  [Text(0.9708203866460458, 0.7053423118404443, 'A'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'B'),
#   Text(-0.49938956806635254, -0.9801071672559598, 'C'),
#   Text(0.8899186877588748, -0.646563785853741, 'D')],
#  [Text(0.5663118922101933, 0.4114496819069258, '20.0%'),
#   Text(-0.42426406871192845, 0.4242640687119285, '35.0%'),
#   Text(-0.2723943098543741, -0.5346039094123416, '25.0%'),
#   Text(0.4854101933230226, -0.3526711559202223, '20.0%')])

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='Country',data=health)
# Out:
# <Axes: xlabel='Country', ylabel='count'>
