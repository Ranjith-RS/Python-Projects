# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
batsman=pd.read_csv("Downloads/ICC Test Batting Figures.csv")

# %%
nba=pd.read_csv("Downloads/nba.csv")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
batsman
# Out:
#          Player Name Country  Matches  Innings  Not Out     Runs High Score  \
# 0       SR Tendulkar   INDIA      200    329.0     33.0  15921.0       248*
# 1         RT Ponting     AUS      168    287.0     29.0  13378.0        257
# 2          JH Kallis      SA      166    280.0     40.0  13289.0        224
# 3           R Dravid   INDIA      164    286.0     32.0  13288.0        270
# 4            AN Cook     ENG      161    291.0     16.0  12472.0        294
# ...              ...     ...      ...      ...      ...      ...        ...
# 2435      CA Snedden      NZ        1      NaN      NaN      NaN          -
# 2436        VN Swamy   INDIA        1      NaN      NaN      NaN          -
# 2437  Usman Shinwari     PAK        1      NaN      NaN      NaN          -
# 2438   CM Willoughby      SA        2      NaN      NaN      NaN          -
# 2439       JW Wilson     AUS        1      NaN      NaN      NaN          -
#
#       Average  Hundred  Fifty  Duck Out  From   End  \
# ...

# %%
batsman.shape
# Out:
# (2440, 14)

# %%
batsman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2440 entries, 0 to 2439
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          2440 non-null   object
#  1   Country              2440 non-null   object
#  2   Matches              2440 non-null   int64
#  3   Innings              2420 non-null   float64
#  4   Not Out              2420 non-null   float64
#  5   Runs                 2420 non-null   float64
#  6   High Score           2440 non-null   object
#  7   Average              2352 non-null   float64
#  8   Hundred              2420 non-null   float64
#  9   Fifty                2420 non-null   float64
#  10  Duck Out             2420 non-null   float64
#  11  From                 2440 non-null   int64
#  12  End                  2440 non-null   int64
#  13  Player Profile'Link  2440 non-null   object
# dtypes: float64(7), int64(3), object(4)
# memory usage: 267.0+ KB

# %%
batsman.describe()
# Out:
#            Matches      Innings      Not Out          Runs      Average  \
# count  2440.000000  2420.000000  2420.000000   2420.000000  2352.000000
# mean     12.597951    20.305372     2.959091    526.302479    17.957866
# std      23.169470    38.591239     5.549319   1602.743846    14.304942
# min       1.000000     1.000000     0.000000      0.000000     0.000000
# 25%       2.000000     3.000000     0.000000     26.000000     8.000000
# 50%       5.000000     8.000000     1.000000     94.000000    14.900000
# 75%      11.000000    18.000000     3.000000    281.000000    24.052500
# max     200.000000   329.000000    52.000000  15921.000000   160.500000
#
#            Hundred        Fifty     Duck Out         From          End
# count  2420.000000  2420.000000  2420.000000  2440.000000  2440.000000
# mean      1.078512     2.337603     2.360744  1967.442623  1970.886066
# std       4.488057     7.772637     3.715607    39.391112    39.519398
# ...

# %%
batsman.isnull().sum()
# Out:
# Player Name             0
# Country                 0
# Matches                 0
# Innings                20
# Not Out                20
# Runs                   20
# High Score              0
# Average                88
# Hundred                20
# Fifty                  20
# Duck Out               20
# From                    0
# End                     0
# Player Profile'Link     0
# dtype: int64

# %%
batsman.duplicated().sum()
# Out:
# 0

# %%
#If innings is null we cant compute the row like runs , avg, not out etc so we are going to drop it
batsman.dropna(subset=['Innings'],inplace=True)

# %%
batsman.isnull().sum()
# Out:
# Player Name             0
# Country                 0
# Matches                 0
# Innings                 0
# Not Out                 0
# Runs                    0
# High Score              0
# Average                68
# Hundred                 0
# Fifty                   0
# Duck Out                0
# From                    0
# End                     0
# Player Profile'Link     0
# dtype: int64

# %%
batsman[batsman.isnull().any(axis=1)]
#here we can clearly saw that avearge is missed due to some mistake
# Out:
#           Player Name Country  Matches  Innings  Not Out  Runs High Score  \
# 1397     Afaq Hussain     PAK        2      4.0      4.0  66.0        35*
# 1506           SG Law     AUS        1      1.0      1.0  54.0        54*
# 1747         CG Halse      SA        3      3.0      3.0  30.0        19*
# 1774        FAW Freer     AUS        1      1.0      1.0  28.0        28*
# 1802        IW Callen     AUS        1      2.0      2.0  26.0        22*
# ...               ...     ...      ...      ...      ...   ...        ...
# 2399           M Ngam      SA        3      1.0      1.0   0.0         0*
# 2403        HJ Rhodes     ENG        2      1.0      1.0   0.0         0*
# 2407       TAP Sekhar   INDIA        2      1.0      1.0   0.0         0*
# 2415  M Venkataramana   INDIA        1      2.0      2.0   0.0         0*
# 2417         P Wilson     AUS        1      2.0      2.0   0.0         0*
#
#       Average  Hundred  Fifty  Duck Out  From   End  \
# ...

# %%
#we are going to calculate the average in cricket
batsman['avg']=batsman['Innings']-batsman['Not Out']
batsman['Avg']=round(batsman['Runs']/batsman['avg'],2)
batsman
# Out:
#           Player Name Country  Matches  Innings  Not Out     Runs High Score  \
# 0        SR Tendulkar   INDIA      200    329.0     33.0  15921.0       248*
# 1          RT Ponting     AUS      168    287.0     29.0  13378.0        257
# 2           JH Kallis      SA      166    280.0     40.0  13289.0        224
# 3            R Dravid   INDIA      164    286.0     32.0  13288.0        270
# 4             AN Cook     ENG      161    291.0     16.0  12472.0        294
# ...               ...     ...      ...      ...      ...      ...        ...
# 2415  M Venkataramana   INDIA        1      2.0      2.0      0.0         0*
# 2416         DW White     ENG        2      2.0      0.0      0.0          0
# 2417         P Wilson     AUS        1      2.0      2.0      0.0         0*
# 2418        CS Wimble      SA        1      2.0      0.0      0.0          0
# 2419       Zahir Khan     AFG        2      4.0      3.0      0.0         0*
#
# ...

# %%
#now we dont want the column named avg , so drop it
batsman.drop(batsman.loc[:, ['Average','avg']].columns, axis=1,inplace=True)
batsman
# Out:
#           Player Name Country  Matches  Innings  Not Out     Runs High Score  \
# 0        SR Tendulkar   INDIA      200    329.0     33.0  15921.0       248*
# 1          RT Ponting     AUS      168    287.0     29.0  13378.0        257
# 2           JH Kallis      SA      166    280.0     40.0  13289.0        224
# 3            R Dravid   INDIA      164    286.0     32.0  13288.0        270
# 4             AN Cook     ENG      161    291.0     16.0  12472.0        294
# ...               ...     ...      ...      ...      ...      ...        ...
# 2415  M Venkataramana   INDIA        1      2.0      2.0      0.0         0*
# 2416         DW White     ENG        2      2.0      0.0      0.0          0
# 2417         P Wilson     AUS        1      2.0      2.0      0.0         0*
# 2418        CS Wimble      SA        1      2.0      0.0      0.0          0
# 2419       Zahir Khan     AFG        2      4.0      3.0      0.0         0*
#
# ...

# %%
batsman.isnull().sum()
# Out:
# Player Name             0
# Country                 0
# Matches                 0
# Innings                 0
# Not Out                 0
# Runs                    0
# High Score              0
# Hundred                 0
# Fifty                   0
# Duck Out                0
# From                    0
# End                     0
# Player Profile'Link     0
# Avg                    11
# dtype: int64

# %%
# still we are left with some more null values in Our DataFrome , so we are going to drop that to
batsman.dropna(subset=['Avg'],inplace=True)
batsman
# Out:
#              Player Name Country  Matches  Innings  Not Out     Runs  \
# 0           SR Tendulkar   INDIA      200    329.0     33.0  15921.0
# 1             RT Ponting     AUS      168    287.0     29.0  13378.0
# 2              JH Kallis      SA      166    280.0     40.0  13289.0
# 3               R Dravid   INDIA      164    286.0     32.0  13288.0
# 4                AN Cook     ENG      161    291.0     16.0  12472.0
# ...                  ...     ...      ...      ...      ...      ...
# 2413  PS Twentyman-Jones      SA        1      2.0      0.0      0.0
# 2414            EJ Tyler     ENG        1      1.0      0.0      0.0
# 2416            DW White     ENG        2      2.0      0.0      0.0
# 2418           CS Wimble      SA        1      2.0      0.0      0.0
# 2419          Zahir Khan     AFG        2      4.0      3.0      0.0
#
#      High Score  Hundred  Fifty  Duck Out  From   End  \
# 0          248*     51.0   68.0      14.0  1989  2013
# ...

# %%
batsman.shape
# Out:
# (2409, 14)

# %%
batsman.loc[batsman.Runs==0.0]
#here we have players with not even score single runs , so we are going to drop it
# Out:
#              Player Name Country  Matches  Innings  Not Out  Runs High Score  \
# 2369         SA Banerjee   INDIA        1      1.0      0.0   0.0          0
# 2370         JE Benjamin     ENG        1      1.0      0.0   0.0          0
# 2371             GE Bond      SA        1      1.0      0.0   0.0          0
# 2372      LA Butterfield      NZ        1      2.0      0.0   0.0          0
# 2373             DW Carr     ENG        1      1.0      0.0   0.0          0
# 2374        GA Chevalier      SA        1      2.0      1.0   0.0         0*
# 2375            SP Davis     AUS        1      1.0      0.0   0.0          0
# 2376            CD Dixon      SA        1      2.0      0.0   0.0          0
# 2377         JH du Preez      SA        2      2.0      0.0   0.0          0
# 2378            GF Grace     ENG        1      2.0      0.0   0.0          0
# 2380             GG Hall      SA        1      1.0      0.0   0.0          0
# ...

# %%
#droping players with zero runs
batsman.drop(batsman[batsman['Runs'] <= 50.0].index,inplace=True)

# %%
#change datatypes of following from float to integer
batsman[['Innings','Not Out','Runs','Hundred','Fifty','Duck Out']]=batsman[['Innings','Not Out','Runs','Hundred','Fifty','Duck Out']].astype(int)

# %%
batsman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1551 entries, 0 to 1550
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          1551 non-null   object
#  1   Country              1551 non-null   object
#  2   Matches              1551 non-null   int64
#  3   Innings              1551 non-null   int32
#  4   Not Out              1551 non-null   int32
#  5   Runs                 1551 non-null   int32
#  6   High Score           1551 non-null   object
#  7   Hundred              1551 non-null   int32
#  8   Fifty                1551 non-null   int32
#  9   Duck Out             1551 non-null   int32
#  10  From                 1551 non-null   int64
#  11  End                  1551 non-null   int64
#  12  Player Profile'Link  1551 non-null   object
#  13  Avg                  1551 non-null   float64
# dtypes: float64(1), int32(6), int64(3), object(4)
# memory usage: 145.4+ KB

# %%
batsman['Country'].unique()
# Out:
# array(['INDIA', 'AUS', 'SA', 'ENG', 'SL', 'WI', 'PAK', 'NZ', 'ZIM',
#        'BDESH', 'AFG', 'IRE'], dtype=object)

# %%
batsman
# Out:
#         Player Name Country  Matches  Innings  Not Out   Runs High Score  \
# 0      SR Tendulkar   INDIA      200      329       33  15921       248*
# 1        RT Ponting     AUS      168      287       29  13378        257
# 2         JH Kallis      SA      166      280       40  13289        224
# 3          R Dravid   INDIA      164      286       32  13288        270
# 4           AN Cook     ENG      161      291       16  12472        294
# ...             ...     ...      ...      ...      ...    ...        ...
# 1546      HM McGirr      NZ        2        1        0     51         51
# 1547  Nasir Jamshed     PAK        2        4        0     51         46
# 1548    DEV Padgett     ENG        2        4        0     51         31
# 1549   JB Robertson      SA        3        6        1     51         17
# 1550    CL Townsend     ENG        2        3        0     51         38
#
#       Hundred  Fifty  Duck Out  From   End  \
# 0          51     68        14  1989  2013
# ...

# %%
batsman.loc[batsman.Hundred>=30,['Player Name','Country','Matches','High Score','Hundred']]
# Out:
#          Player Name Country  Matches High Score  Hundred
# 0       SR Tendulkar   INDIA      200       248*       51
# 1         RT Ponting     AUS      168        257       41
# 2          JH Kallis      SA      166        224       45
# 3           R Dravid   INDIA      164        270       36
# 4            AN Cook     ENG      161        294       33
# 5      KC Sangakkara      SL      134        319       38
# 6            BC Lara      WI      131       400*       34
# 7      S Chanderpaul      WI      164       203*       30
# 8   DPMD Jayawardene      SL      149        374       34
# 10          SR Waugh     AUS      168        200       32
# 11       SM Gavaskar   INDIA      125       236*       34
# 12       Younis Khan     PAK      118        313       34
# 21         ML Hayden     AUS      103        380       30

# %%
sns.barplot(x=batsman['Country'],y=batsman['Hundred'],data=batsman)
sns.set(rc = {'figure.figsize':(5,20)})
plt.title("Hundred Country Wise")
plt.show()

# %%
plt.title("Runs Country Wise")
sns.barplot(x=batsman['Country'],y=batsman['Runs'],data=batsman)
plt.figure(figsize=(10,8))

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(batsman['Hundred'])
plt.xlabel("Players")
plt.ylabel("Runs")
# Out:
# Text(0, 0.5, 'Runs')

# %%
batsman
# Out:
#         Player Name Country  Matches  Innings  Not Out   Runs High Score  \
# 0      SR Tendulkar   INDIA      200      329       33  15921       248*
# 1        RT Ponting     AUS      168      287       29  13378        257
# 2         JH Kallis      SA      166      280       40  13289        224
# 3          R Dravid   INDIA      164      286       32  13288        270
# 4           AN Cook     ENG      161      291       16  12472        294
# ...             ...     ...      ...      ...      ...    ...        ...
# 1546      HM McGirr      NZ        2        1        0     51         51
# 1547  Nasir Jamshed     PAK        2        4        0     51         46
# 1548    DEV Padgett     ENG        2        4        0     51         31
# 1549   JB Robertson      SA        3        6        1     51         17
# 1550    CL Townsend     ENG        2        3        0     51         38
#
#       Hundred  Fifty  Duck Out  From   End  \
# 0          51     68        14  1989  2013
# ...

# %%
plt.figure(figsize=(8,8))
sns.lineplot(x='Country',y='Avg',data=batsman)
# Out:
# <Axes: xlabel='Country', ylabel='Avg'>
